# %% [markdown]
# <a href="https://colab.research.google.com/github/alonso4763/IA_IB_199425/blob/main/PRACTICA_5_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importamos la librería OpenCV para el procesamiento de imágenes
#e importamos matplotlib.pyplot como 'plt' para visualizar imágenes en gráficos
import cv2
import matplotlib.pyplot as plt

# %%
# Cargar imagen oscura
img_bgr = cv2.imread('/content/Ilustracion 1.jpg')
img_rgb = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)

# Convertir la imagen al espacio de color HSV (Hue, Saturation, Value)
img_hsv = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2HSV)

# # Separar los tres canales del espacio HSV: tono (h), saturación (s) y valor/brillo (v)
h, s, v = cv2.split(img_hsv)

# Ecualizar solo el canal de valor (brillo)
v_eq = cv2.equalizeHist(v)

# Combinar canales con el V ecualizado
img_hsv_eq = cv2.merge([h, s, v_eq])

# Convertir de nuevo a BGR y luego a RGB para visualización
img_eq_bgr = cv2.cvtColor(img_hsv_eq, cv2.COLOR_HSV2BGR)
img_eq_rgb = cv2.cvtColor(img_eq_bgr, cv2.COLOR_BGR2RGB)

# %%
# Mostrar imágenes original y mejorada
plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.imshow(img_rgb)
plt.title('Imagen original')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(img_eq_rgb)
plt.title('Imagen mejorada (Ecualización V)')
plt.axis('off')

plt.tight_layout()
plt.show()

# %%
# Importamos la librería OpenCV para el procesamiento de imágenes
#e importamos matplotlib.pyplot como 'plt' para visualizar imágenes en gráficos
import cv2
import matplotlib.pyplot as plt

# %%
# Cargar imagen oscura
img_bgr = cv2.imread('/content/Ilustracion 2.jpg')
img_rgb = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)

# Convertir la imagen al espacio de color HSV (Hue, Saturation, Value)
img_hsv = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2HSV)

# # Separar los tres canales del espacio HSV: tono (h), saturación (s) y valor/brillo (v)
h, s, v = cv2.split(img_hsv)

# Ecualizar solo el canal de valor (brillo)
v_eq = cv2.equalizeHist(v)

# Combinar canales con el V ecualizado
img_hsv_eq = cv2.merge([h, s, v_eq])

# Convertir de nuevo a BGR y luego a RGB para visualización
img_eq_bgr = cv2.cvtColor(img_hsv_eq, cv2.COLOR_HSV2BGR)
img_eq_rgb = cv2.cvtColor(img_eq_bgr, cv2.COLOR_BGR2RGB)

# %%
# Mostrar imágenes original y mejorada
plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.imshow(img_rgb)
plt.title('Imagen original')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(img_eq_rgb)
plt.title('Imagen mejorada (Ecualización V)')
plt.axis('off')

plt.tight_layout()
plt.show()

# %%
# Importamos la librería OpenCV para el procesamiento de imágenes
#e importamos matplotlib.pyplot como 'plt' para visualizar imágenes en gráficos
import cv2
import matplotlib.pyplot as plt

# %%
# Cargar imagen oscura
img_bgr = cv2.imread('/content/Iustracion 3.jpg')
img_rgb = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)

# Convertir la imagen al espacio de color HSV (Hue, Saturation, Value)
img_hsv = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2HSV)

# # Separar los tres canales del espacio HSV: tono (h), saturación (s) y valor/brillo (v)
h, s, v = cv2.split(img_hsv)

# Ecualizar solo el canal de valor (brillo)
v_eq = cv2.equalizeHist(v)

# Combinar canales con el V ecualizado
img_hsv_eq = cv2.merge([h, s, v_eq])

# Convertir de nuevo a BGR y luego a RGB para visualización
img_eq_bgr = cv2.cvtColor(img_hsv_eq, cv2.COLOR_HSV2BGR)
img_eq_rgb = cv2.cvtColor(img_eq_bgr, cv2.COLOR_BGR2RGB)

# %%
# Mostrar imágenes original y mejorada
plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.imshow(img_rgb)
plt.title('Imagen original')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(img_eq_rgb)
plt.title('Imagen mejorada (Ecualización V)')
plt.axis('off')

plt.tight_layout()
plt.show()
