# %% [markdown]
# <a href="https://colab.research.google.com/github/alonso4763/IA_IB_199425/blob/main/Assigments/Decision_Tree.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1. Cargar las bibliotecas necesarias
import pandas as pd
import numpy as np
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, classification_report
from sklearn import tree
import matplotlib.pyplot as plt

# %%
# 2. Cargar el conjunto de datos Breast Cancer Wisconsin (Diagnostic)
cancer_data = load_breast_cancer()
data = pd.DataFrame(cancer_data.data, columns=cancer_data.feature_names)
labels = pd.Series(cancer_data.target)

# %%
# 3. Preprocesamiento de datos (división de datos en entrenamiento y prueba)
train_data, test_data, train_labels, test_labels = train_test_split(data, labels, test_size=0.2, random_state=42)

# %%
# 4. Selección y entrenamiento del modelo (Árbol de decisión)
decision_tree_model = DecisionTreeClassifier(random_state=42)
decision_tree_model.fit(train_data, train_labels)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
# 5. Prueba del modelo (predicciones y evaluación)
predictions = decision_tree_model.predict(test_data)

# %%
# Cálculo de la precisión y el informe de clasificación
accuracy = accuracy_score(test_labels, predictions)
print(f'Accuracy: {accuracy * 100:.2f}%')

print("Classification Report:")
print(classification_report(test_labels, predictions, target_names=cancer_data.target_names))
# Out:
# Accuracy: 94.74%
# Classification Report:
#               precision    recall  f1-score   support
#
#    malignant       0.93      0.93      0.93        43
#       benign       0.96      0.96      0.96        71
#
#     accuracy                           0.95       114
#    macro avg       0.94      0.94      0.94       114
# weighted avg       0.95      0.95      0.95       114

# %%
# 6. Visualización gráfica del árbol de decisión
plt.figure(figsize=(20, 10), dpi=300)
tree.plot_tree(decision_tree_model, filled=True, feature_names=cancer_data.feature_names, class_names=cancer_data.target_names, rounded=True)
plt.show()
